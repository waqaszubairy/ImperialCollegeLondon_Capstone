# %%
print ("This is the test program")
# Out:
# This is the test program

# %%
print ("This Repository is created for Imperial College London Course")
# Out:
# This Repository is created for Imperial College London Course

# %%
print ("Program name is Artificial Intelligence and MI Learning Course")
# Out:
# Program name is Artificial Intelligence and MI Learning Course
